# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading dataset

# %%
data=pd.read_csv('vgsales.csv')
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.shape
# Out:
# (16598, 11)

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %% [markdown]
# # Checking missing values in dataset

# %%
missing_values=data.isna().sum()
missing_values
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data['Year'].value_counts()
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1259
# 2007.0    1202
# 2011.0    1139
# 2006.0    1008
# 2005.0     941
# 2002.0     829
# 2003.0     775
# 2004.0     763
# 2012.0     657
# 2015.0     614
# 2014.0     582
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     344
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1983.0      17
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1984.0      14
# 1985.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %% [markdown]
# # Dropping all the missing Values

# %%
df=data.dropna()
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.isna().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# # Correlation of data

# %%
cor_data=data.corr()
sns.heatmap(cor_data, annot=True,cmap='RdYlBu_r')
plt.show()

# %% [markdown]
# # Working with Categorical datas

# %%
data['Genre'].value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
data['Platform'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %% [markdown]
# # Target encoding on categorical datas

# %%
data['Publisher'].value_counts()
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Ivolgamus                          1
# Just Flight                        1
# Strategy First                     1
# Ertain                             1
# Monte Christo Multimedia           1
# Name: Publisher, Length: 578, dtype: int64

# %%
df['Publisher'] = df['Publisher'].astype(str).str[0]
df.groupby(['Publisher'])['Global_Sales'].mean()
Encoded_Lables = df.groupby(['Publisher'])  ['Global_Sales'].mean().sort_values().index
Encoded_Lables_Ranks = { k:i for i, k in enumerate(Encoded_Lables, 0) }
df['Publisher_Encoded'] = df['Publisher'].map(Encoded_Lables_Ranks)
df = df.drop('Publisher', axis = 1)

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df['Platform'] = df['Platform'].astype(str).str[0]
df.groupby(['Platform'])['Global_Sales'].mean()
Encoded_Lables = df.groupby(['Platform'])  ['Global_Sales'].mean().sort_values().index
Encoded_Lables_Ranks = { k:i for i, k in enumerate(Encoded_Lables, 0) }
df['Platform_encoded'] = df['Platform'].map(Encoded_Lables_Ranks)
df = df.drop('Platform', axis = 1)

# %%
df
# Out:
#         Rank                                              Name    Year  \
# 0          1                                        Wii Sports  2006.0
# 1          2                                 Super Mario Bros.  1985.0
# 2          3                                    Mario Kart Wii  2008.0
# 3          4                                 Wii Sports Resort  2009.0
# 4          5                          Pokemon Red/Pokemon Blue  1996.0
# ...      ...                                               ...     ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5  2002.0
# 16594  16597                     Men in Black II: Alien Escape  2003.0
# 16595  16598  SCORE International Baja 1000: The Official Game  2008.0
# 16596  16599                                        Know How 2  2010.0
# 16597  16600                                  Spirits & Spells  2003.0
#
#               Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# ...

# %%
df['Genre'] = df['Genre'].astype(str).str[0]
df.groupby(['Genre'])['Global_Sales'].mean()
Encoded_Lables = df.groupby(['Genre'])  ['Global_Sales'].mean().sort_values().index
Encoded_Lables_Ranks = { k:i for i, k in enumerate(Encoded_Lables, 0) }
df['Genre_encoded'] = df['Genre'].map(Encoded_Lables_Ranks)
df = df.drop('Genre', axis = 1)

# %%
df
# Out:
#         Rank                                              Name    Year  \
# 0          1                                        Wii Sports  2006.0
# 1          2                                 Super Mario Bros.  1985.0
# 2          3                                    Mario Kart Wii  2008.0
# 3          4                                 Wii Sports Resort  2009.0
# 4          5                          Pokemon Red/Pokemon Blue  1996.0
# ...      ...                                               ...     ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5  2002.0
# 16594  16597                     Men in Black II: Alien Escape  2003.0
# 16595  16598  SCORE International Baja 1000: The Official Game  2008.0
# 16596  16599                                        Know How 2  2010.0
# 16597  16600                                  Spirits & Spells  2003.0
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# ...

# %%
df=df.drop(['Name'],axis=1)
df
# Out:
#         Rank    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          1  2006.0     41.49     29.02      3.77         8.46         82.74
# 1          2  1985.0     29.08      3.58      6.81         0.77         40.24
# 2          3  2008.0     15.85     12.88      3.79         3.31         35.82
# 3          4  2009.0     15.75     11.01      3.28         2.96         33.00
# 4          5  1996.0     11.27      8.89     10.22         1.00         31.37
# ...      ...     ...       ...       ...       ...          ...           ...
# 16593  16596  2002.0      0.01      0.00      0.00         0.00          0.01
# 16594  16597  2003.0      0.01      0.00      0.00         0.00          0.01
# 16595  16598  2008.0      0.00      0.00      0.00         0.00          0.01
# 16596  16599  2010.0      0.00      0.01      0.00         0.00          0.01
# 16597  16600  2003.0      0.01      0.00      0.00         0.00          0.01
#
# ...

# %% [markdown]
# # Checking for Outliers

# %%
fig = plt.figure(figsize =(15, 12))
plt.subplot(3,4,1)
bp=sns.boxplot(df['NA_Sales'])
plt.subplot(3,4,2)
bp=sns.boxplot(df['EU_Sales'])
plt.subplot(3,4,3)
bp=sns.boxplot(df['JP_Sales'])
plt.subplot(3,4,4)
bp=sns.boxplot(df['Other_Sales'])
plt.subplot(3,4,5)
bp=sns.boxplot(df['Platform_encoded'])
plt.subplot(3,4,6)
bp=sns.boxplot(df['Genre_encoded'])
plt.subplot(3,4,7)
bp=sns.boxplot(df['Global_Sales'])
plt.subplot(3,4,8)
bp=sns.boxplot(df['Publisher_Encoded'])
plt.show()

# %%
df.dtypes
# Out:
# Rank                   int64
# Year                 float64
# NA_Sales             float64
# EU_Sales             float64
# JP_Sales             float64
# Other_Sales          float64
# Global_Sales         float64
# Publisher_Encoded      int64
# Platform_encoded       int64
# Genre_encoded          int64
# dtype: object

# %% [markdown]
# # Applying Linear Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso 
from sklearn.ensemble import RandomForestRegressor

# %%
# X = feature values, all the columns except the species column
X = df.drop(['Global_Sales'],axis=1)
display(X)

# y = target values, only the species column
y = df.iloc[:, 7]
display(y)
# Out:
#         Rank    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0          1  2006.0     41.49     29.02      3.77         8.46
# 1          2  1985.0     29.08      3.58      6.81         0.77
# 2          3  2008.0     15.85     12.88      3.79         3.31
# 3          4  2009.0     15.75     11.01      3.28         2.96
# 4          5  1996.0     11.27      8.89     10.22         1.00
# ...      ...     ...       ...       ...       ...          ...
# 16593  16596  2002.0      0.01      0.00      0.00         0.00
# 16594  16597  2003.0      0.01      0.00      0.00         0.00
# 16595  16598  2008.0      0.00      0.00      0.00         0.00
# 16596  16599  2010.0      0.00      0.01      0.00         0.00
# 16597  16600  2003.0      0.01      0.00      0.00         0.00
#
#        Publisher_Encoded  Platform_encoded  Genre_encoded
# 0                     38                 7              3
# 1                     38                 9              5
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
regr = linear_model.LinearRegression()
fitregr=regr.fit(x_train, y_train)
predregrtrain=fitregr.predict(x_train)
predregrtest=fitregr.predict(x_test)

# %%
print('Linear model intercept: {} and the coefficients are: {}'
     .format(fitregr.intercept_,fitregr.coef_))
# Out:
# Linear model intercept: 1.2654766123887384e-11 and the coefficients are: [-1.44571108e-15 -3.34770950e-16  1.63493205e-16  1.12375545e-15
#  -1.16995022e-15 -4.32766212e-16  1.00000000e+00  1.25075560e-16
#   3.31656018e-17]

# %%
train_set_r2 = r2_score(y_train, predregrtrain)
print('Linear model, R2 train score is : {}'.format(train_set_r2))
test_set_r2 = r2_score(y_test, predregrtest)
print('Linear model, R2 test score is : {}'.format(test_set_r2))
# Out:
# Linear model, R2 train score is : 1.0
# Linear model, R2 test score is : 1.0

# %% [markdown]
# # Accuracy after applying Linear Regression model is 100 %

# %% [markdown]
# # Applying XGBoost Model

# %%
import xgboost
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
model = XGBClassifier()
model.fit(x_train, y_train)
# Out:
# [11:23:16] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=4, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
# ...

# %%
y_pred = model.predict(x_test)
predictions = [round(value) for value in y_pred]
y_pred_train=model.predict(x_train)

# %%
test_set_r2 = r2_score(y_train, y_pred_train)
print('xgboost model, R2 train score is : {}'.format(test_set_r2))
test_set_r2 = r2_score(y_test, y_pred)
print('xgboost model, R2 test score is : {}'.format(test_set_r2))
# Out:
# xgboost model, R2 train score is : 1.0
# xgboost model, R2 test score is : 0.9985726962343949

# %% [markdown]
# # Accuracy on XGB is 99.85 %
